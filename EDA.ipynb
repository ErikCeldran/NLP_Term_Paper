# %% [markdown]
# Exploratory Data Analysis: Look at records and its columns, Create histogram showing the distribution of the count of reviews across the scores

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/SHOPEE_REVIEWS.csv', index_col=0)

# %%
df.sample(10)
# Out:
#                                               review_text  review_rating  \
# 211921  your seller sucks! Everyone should know that s...              1
# 768714                                   Excellent app☺☺☺              5
# 453314                                            amazing              5
# 552017                                      Its very nice              5
# 717587  shopee should make a ratings for delivery ride...              2
# 626708  sa mga ng daang araw mga order q mga cra dumti...              5
# 407613                                               Yeah              4
# 607412  It's good I use this app in another account. N...              5
# 186627                                         It's good.              4
# 531536                                                 Ok              5
#
#                     author_id    author_name author_app_version  \
# 211921  117687*********909756  A Google user            2.47.31
# ...

# %%
hist = df["review_rating"].hist(bins=5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 782079 entries, 0 to 782078
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   review_text          781838 non-null  object
#  1   review_rating        782079 non-null  int64
#  2   author_id            782075 non-null  object
#  3   author_name          782079 non-null  object
#  4   author_app_version   596741 non-null  object
#  5   review_datetime_utc  782079 non-null  object
#  6   review_likes         782079 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 47.7+ MB

# %%
df.isnull()
# Out:
#         review_text  review_rating  author_id  author_name  \
# 0             False          False      False        False
# 1             False          False      False        False
# 2             False          False      False        False
# 3             False          False      False        False
# 4             False          False      False        False
# ...             ...            ...        ...          ...
# 782074        False          False      False        False
# 782075        False          False      False        False
# 782076        False          False      False        False
# 782077        False          False      False        False
# 782078        False          False      False        False
#
#         author_app_version  review_datetime_utc  review_likes
# 0                     True                False         False
# 1                    False                False         False
# 2                    False                False         False
# ...
